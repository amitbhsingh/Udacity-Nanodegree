# %%
import pandas as pd
data=pd.read_csv('house_prices.csv')

# %%
data
# Out:
#       house_id neighborhood  area   ...     bathrooms      style    price
# 0         1112            B  1188   ...             2      ranch   598291
# 1          491            B  3512   ...             3  victorian  1744259
# 2         5952            B  1134   ...             2      ranch   571669
# 3         3525            A  1940   ...             2      ranch   493675
# 4         5108            B  2208   ...             4  victorian  1101539
# 5         7507            C  1785   ...             2      lodge   455235
# 6         4964            B  2996   ...             3  victorian  1489871
# 7         7627            C  3263   ...             3  victorian   821931
# 8         6571            A  1159   ...             2      ranch   299903
# 9         5220            A  1248   ...             2  victorian   321975
# 10        3223            A  3432   ...             4  victorian   863995
# 11        1540            A  3853   ...             3  victorian   968251
# ...
